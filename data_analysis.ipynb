# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Data/forms_cleaned.csv')
df.head()
# Out:
#   ¿Con qué frecuencia practicas tu instrumento o canto?  \
# 0                                       Casi siempre
# 1                                       Casi siempre
# 2                                       Casi siempre
# 3                                            A veces
# 4                                       Casi siempre
#
#   ¿Qué tipo de recursos utilizas para estudiar música?  \
# 0                                      Libros;Videos
# 1                                      Libros;Videos
# 2                          Libros;Videos;Paginas web
# 3                                             Videos
# 4                                 Videos;Paginas web
#
#   ¿Conoce estudios de grabación y de producción musical en la ciudad de Cali?  \
# 0                                                 Sí
# 1                                                 Sí
# 2                                                 Sí
# 3                                                 Sí
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 11 columns):
#  #   Column                                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                                               --------------  -----
#  0   ¿Con qué frecuencia practicas tu instrumento o canto?                                                                                                74 non-null     object
#  1   ¿Qué tipo de recursos utilizas para estudiar música?                                                                                                 74 non-null     object
# ...

# %%
# show in a graph the column 3 of data frame binary
sns.set_style('whitegrid')
fig = sns.countplot(x='¿Ha asistido a estudios de grabación y/o de producción musical?', data=df)

save_figure =  fig.get_figure()
save_figure.savefig('./Images/Question3.png')

# %%
# Data
labels = 'No', 'Sí'
sizes = df['¿Crees que hay suficientes oportunidades para los estudiantes de música para conectarse con otros músicos y colaborar en proyectos?'].value_counts()

print(sizes)

# Plot
fig, ax = plt.subplots()

ax.set_title('¿Crees que hay suficientes oportunidades para los estudiantes de música para conectarse con otros músicos y colaborar en proyectos?')
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Show plot
plt.show()
save_figure =  fig.get_figure()
save_figure.savefig('./Images/piechart1.png')
# Out:
# No    47
# Sí    27
# Name: ¿Crees que hay suficientes oportunidades para los estudiantes de música para conectarse con otros músicos y colaborar en proyectos?, dtype: int64

# %%
# Data
labels = ['Sí']
sizes = df['¿Piensas que los estudios de grabación y/o de producción musical da espacio para conocer a personas que puedan ayudar a tu crecimiento profesional?'].value_counts()

print(sizes)

# Plot
fig, ax = plt.subplots()

ax.set_title('¿Piensas que los estudios de grabación y/o de producción musical da espacio para conocer a personas que puedan ayudar a tu crecimiento profesional?')
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Show plot
plt.show()
save_figure =  fig.get_figure()
save_figure.savefig('./Images/piechart2.png')
# Out:
# Sí    60
# Name: ¿Piensas que los estudios de grabación y/o de producción musical da espacio para conocer a personas que puedan ayudar a tu crecimiento profesional?, dtype: int64

# %%
# Data
labels = ['Casi nunca', 'A veces', 'Casi siempre', 'Siempre']
sizes = df['¿Con qué frecuencia practicas tu instrumento o canto?'].value_counts()

print(sizes)

# Plot
fig, ax = plt.subplots()

ax.set_title('¿Con qué frecuencia practicas tu instrumento o canto?')
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Show plot
plt.show()
save_figure =  fig.get_figure()
save_figure.savefig('./Images/piechart3.png')
# Out:
# Casi siempre    38
# A veces         20
# Siempre         10
# Casi nunca       6
# Name: ¿Con qué frecuencia practicas tu instrumento o canto?, dtype: int64

# %%
# pass to an array '¿Qué tipo de recursos utilizas para estudiar música?'?
values = df['¿Qué tipo de recursos utilizas para estudiar música?'].value_counts()
print(values)
# Out:
# Videos;Paginas web                      23
# Videos                                  22
# Libros;Videos                           16
# Libros;Videos;Paginas web               10
# Paginas web                              2
# Videos;Paginas web;Llamar a un amigo     1
# Name: ¿Qué tipo de recursos utilizas para estudiar música?, dtype: int64

# %%
# videos, Paginas web, Libros, Otros
videos_sum = values[0] + values[1] + values[2] + values[3] + values[5]
web_sum = values[0] + values[3] + values[4] + values[5]
books_sum = values[2] + values[3]
others_sum = values[5]

values_sum = [videos_sum, web_sum, books_sum, others_sum]
print(values_sum)
# Out:
# [72, 36, 26, 1]

# %%
#histogram with values_sum
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title('¿Qué tipo de recursos utilizas para estudiar música?')
ax.set_ylabel('Frecuencia')
ax.set_xlabel('Recursos')
ax.bar(['Videos', 'Paginas web', 'Libros', 'Otros'], values_sum)
plt.show()
# save the figure
save_figure =  fig.get_figure()
save_figure.savefig('./Images/Question6.png')

# %%
# Data
labels = ['Sí', 'No']
sizes = df['¿Conoce estudios de grabación y de producción musical en la ciudad de Cali?'].value_counts()

print(sizes)

# Plot
fig, ax = plt.subplots()

ax.set_title('¿Conoce estudios de grabación y de producción musical en la ciudad de Cali?')
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Show plot
plt.show()
save_figure =  fig.get_figure()
save_figure.savefig('./Images/piechart4.png')
# Out:
# Sí    68
# No     6
# Name: ¿Conoce estudios de grabación y de producción musical en la ciudad de Cali?, dtype: int64

# %%
# pass to an array '¿Por qué no asistes a estudios de grabación y/o de producción musical?'
values = df['¿Por qué no asistes a estudios de grabación y/o de producción musical?'].value_counts()
print(values)
# Out:
# Por la poca adecuacion del espacio                                       3
# Por el costo;La ubicación del sitio                                      3
# Por el costo                                                             3
# No me he visto en la necesidad, lo que hago lo hago en mi home studio    1
# Por el costo;Por la poca adecuacion del espacio                          1
# No conozco                                                               1
# Name: ¿Por qué no asistes a estudios de grabación y/o de producción musical?, dtype: int64

# %%
# Por el costo, Por la poca adecuacion del espacio, La ubicación del sitio, Otro
cost_sum = values[1] + values[2] + values[4]
space_sum = values[0] + values[4]
location_sum = values[1]
other_sum = values[3] + values[5]

values_sum = [cost_sum, space_sum, location_sum, other_sum]
print(values_sum)
# Out:
# [7, 4, 3, 2]

# %%
# histogram with values
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title('¿Por qué no asistes a estudios de grabación y/o de producción musical?')
ax.set_ylabel('Frecuencia')
ax.set_xlabel('Razones')
ax.bar(['costo', 'poca adecuacion', 'ubicación', 'Otro'], values_sum)
plt.show()

# save the figure
save_figure =  fig.get_figure()
save_figure.savefig('./Images/Question8.png')

# %%
#Data
labels = ['En casa']
sizes = df['¿Que otras alternativas de estudios de grabación haz utilizado?'].value_counts()

print(sizes)

# Plot
fig, ax = plt.subplots()

ax.set_title('¿Que otras alternativas de estudios de grabación haz utilizado?')
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Show plot
plt.show()
save_figure =  fig.get_figure()
save_figure.savefig('./Images/piechart5.png')
# Out:
# En casa    14
# Name: ¿Que otras alternativas de estudios de grabación haz utilizado?, dtype: int64

# %%
# Data
labels = ['Casi nunca', 'A veces', 'Casi siempre', 'Siempre']
sizes = df['¿Que tan frecuente usa estos espacios?'].value_counts()

print(sizes)

# Plot
fig, ax = plt.subplots()

ax.set_title('¿Que tan frecuente usa estos espacios?')
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Show plot
plt.show()
save_figure =  fig.get_figure()
save_figure.savefig('./Images/piechart6.png')
# Out:
# A veces         34
# Casi siempre    12
# Casi nunca      10
# Siempre          4
# Name: ¿Que tan frecuente usa estos espacios?, dtype: int64

# %%
# Data
labels = ['Sí']
sizes = df['¿Piensas que los estudios de grabación y/o de producción musical da espacio para conocer a personas que puedan ayudar a tu crecimiento profesional?'].value_counts()

print(sizes)

# Plot
fig, ax = plt.subplots()

ax.set_title('¿Piensas que los estudios de grabación y/o de producción musical da espacio para conocer a personas que puedan ayudar a tu crecimiento profesional?')
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Show plot
plt.show()

save_figure =  fig.get_figure()
save_figure.savefig('./Images/piechart7.png')
# Out:
# Sí    60
# Name: ¿Piensas que los estudios de grabación y/o de producción musical da espacio para conocer a personas que puedan ayudar a tu crecimiento profesional?, dtype: int64

# %%
#Data
labels = ['Sí', 'No']
sizes = df['¿Piensas que el costo/beneficio de los estudios de grabación y/o de producción musical es justo?.1'].value_counts()

print(sizes)

# Plot
fig, ax = plt.subplots()

ax.set_title('¿Piensas que el costo/beneficio de los estudios de grabación y/o de producción musical es justo?')
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Show plot
plt.show()
save_figure =  fig.get_figure()
save_figure.savefig('./Images/piechart8.png')
# Out:
# Sí    56
# No    18
# Name: ¿Piensas que el costo/beneficio de los estudios de grabación y/o de producción musical es justo?.1, dtype: int64
